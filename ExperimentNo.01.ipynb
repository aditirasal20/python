# %%
name = "Aditi"
print("My name is " +name)
# Out:
# My name is Aditi

# %%
fruits=["apple","banana","cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
person = {"Name" : "Aditi", "age":20, "city": "Crawley"}
print(person)
# Out:
# {'Name': 'Aditi', 'age': 20, 'city': 'Crawley'}

# %%
numbers=(1,2,3)
print(numbers)
# Out:
# (1, 2, 3)

# %%
|
